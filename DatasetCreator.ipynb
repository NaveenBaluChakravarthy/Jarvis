# %%
# Importing the libraries
import spacy
import pandas as pd
import nltk
#nltk.download('punkt')
from nltk.tokenize import sent_tokenize

# %%
# Defining custom variables
dataset = "IronMan is the first in the series that would become known as the MarvelCinematicUniverse. The movie is the origin story of Tony Stark, of birth Name Anthony Edward Stark as Iron Man. The movie begins with a motorcade of army vehicles in the Kunar Province of Afghanistan. Tony Stark chooses to travel in a fun-vee rather than a heavily protected humvee. Tony Stark feels like being taken to a court martial when the army personnel in the fun-vee maintain silence. Forrest is the first in the car to break the silence. There is a lady officer in the car who Tony Stark mistakes to be a man. When asked about going twelve to twelve with last year's Maxim Cover Models, Tony Stark answers that March and him had a scheduling conflict but the Christmas cover was twins. Forrest takes a picture with Tony Stark. Tony Stark advises Forrest not to put the photos up on MySpace page. Tony Stark says not to throw up any gang signs when Forrest shows a peace sign. Tony Stark quirks 'I will be out of a job with peace'. The motorcade in which Tony Stark was in, was ambushed. A bomb manufactured by his company, Stark Industries exploded and the shrapnel from the bomb pierced Tony Stark's body at several places. When Tony Stark woke up, he realized that he was taken prisoner by a group of terrorists. Tony Stark is a visionary, a genius and an American patriot. Even from an early age, as the son of legendary weapons, developer Howard Stark quickly stole the spotlight with his brilliant and unique mind. At age four, he built his first circuit board. At age six, his first engine. And at 17, he graduated summa cum laude from MIT. Howard Stark's lifelong friend and ally, Obadiah Stane, steps in to help fill the gap left by the legendary founder, until, at age 21, the prodigal son returns and is anointed the new CEO of Stark Industries. With the keys to the kingdom, Tony ushers in a new era for his father's legacy, creating smarter weapons, advanced robotics, satellite targeting. Today, Tony Stark has changed the face of the weapons industry, by ensuring freedom and protecting America and her interests around the globe."
corpus = sent_tokenize(dataset)

# %%
x = len(corpus)
i = 1
nlp = spacy.load('en_core_web_sm')
doc = nlp(corpus[i])
for word in doc:
  print([word, word.ent_type_, word.ent_iob_, word.pos_])
# Out:
# [The, '', 'O', 'DET']
# [movie, '', 'O', 'NOUN']
# [is, '', 'O', 'AUX']
# [the, '', 'O', 'DET']
# [origin, '', 'O', 'NOUN']
# [story, '', 'O', 'NOUN']
# [of, '', 'O', 'ADP']
# [Tony, 'PERSON', 'B', 'PROPN']
# [Stark, 'PERSON', 'I', 'PROPN']
# [,, '', 'O', 'PUNCT']
# [of, '', 'O', 'ADP']
# [birth, '', 'O', 'NOUN']
# [Name, '', 'O', 'NOUN']
# [Anthony, 'PERSON', 'B', 'PROPN']
# [Edward, 'PERSON', 'I', 'PROPN']
# [Stark, 'PERSON', 'I', 'PROPN']
# [as, '', 'O', 'SCONJ']
# [Iron, 'PERSON', 'B', 'PROPN']
# [Man, 'PERSON', 'I', 'PROPN']
# [., '', 'O', 'PUNCT']
